# %%
nums = [10,20,50,10,10]

# %%
x_bar = sum(nums)/len(nums)
x_bar
# Out:
# 20.0

# %%
total = 0
for num in nums:
    total += (num - x_bar)**2
total
# Out:
# 1200.0

# %%
1200/(len(nums) - 1)
# Out:
# 300.0

# %%
sd = 300**.5

# %%
def zi(numlist):
    all = []
    for num in numlist:
        all.append((num-20)/(17.32/(5**.5)))
    return all

# %%
zi([10,20,50,10,10])
# Out:
# [-1.291032319572627,
#  0.0,
#  3.8730969587178805,
#  -1.291032319572627,
#  -1.291032319572627]
