# %%
import mathematics as math
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-14-778b0df20783> in <module>
# ----> 1 import mathematics as math
#
# ModuleNotFoundError: No module named 'mathematics'

# %%
x = [10,5]
y = [5,6]

# %%
def distance(x, y):
    step_one = (math.sqrt(x[0] - x[1])) + (math.sqrt(y[0] - y[1]))
    return step_one

# %%
distance(x, y)
